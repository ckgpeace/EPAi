# %% [markdown]
# ## Session14
# ### Objective 1:

# %% [markdown]
# Refactor the Polygon class so that all the calculated properties are lazy properties, i.e. they should still be calculated properties, but they should not have to get recalculated more than once (since we made our Polygon class "immutable").

# %% [markdown]
# ### Polygon1 module implement the objectives

# %% [markdown]
# ##### Example1:

# %%
# Importing the module
import polygon1 as poly1

# %%
#Creating one instance of the polygon
print('setting instance for one polygon')
p1 = poly1.polygon1(7,3)

# Calling area for the first time
print('\n')
print(f'Calling Area function for the first time: {p1.area}')


# Calling area for the second time
print('\n')
print(f'Calling Area function for the 2nd time: {p1.area}')


# Calling Apothem for the first time
print('\n')
print(f'Calling Apothem function for the 1st time: {p1.apothem}')
# Out:
# setting instance for one polygon
#
#
# Calling Area function for the first time: 24.627691697742943
#
#
# Calling Area function for the 2nd time: 24.627691697742943
#
#
# Calling Apothem function for the 1st time: 2.7029066037072575

# %% [markdown]
# **Note:**
#
# Above we can say that even we called Apothem for the **first time**, it uses the previous stored value while calling Area function

# %% [markdown]
# #### Example2:

# %%
#Creating one instance of the polygon
print('setting instance for one polygon')
p1 = poly1.polygon1(8,3)


# Calling Apothem for the first time
print('\n')
print(f'Calling Apothem function for the 1st time:{p1.apothem} ')

# Calling Apothem for the 2nd time
print('\n')
print(f'Calling Apothem function for the 2nd time:{p1.apothem} ')
# Out:
# setting instance for one polygon
#
#
# Calling Apothem function for the 1st time:2.77163859753386
#
#
# Calling Apothem function for the 2nd time:2.77163859753386

# %%
#Creating one instance of the polygon
print('setting instance for one polygon')
p1 = poly1.polygon1(8,8)

print(p1.perimeter)
# Out:
# setting instance for one polygon
# 48.98347934273149

# %% [markdown]
# ## Objective 2:
# Refactor the Polygons (sequence) type, into an iterable. Make sure also that the elements in the iterator are computed lazily - i.e. you can no longer use a list as an underlying storage mechanism for your polygons.
#
# You'll need to implement both an iterable, and an iterator.

# %% [markdown]
# #### NOTE:
# The iterable and iterator are implemented in the module i.e. **`polygon2`** . Please find below few examples of the this module.

# %%
# Importing module 'polygon2'
import polygon2 as poly2

# %%
# Example 1

# Creating an instance of polygon2

n = 8
r = 4
p1 = poly2.polygon2(n,r)

# Finding the max efficiency polygon
l = list(p1.max_efficiency_polygon)
print(f'The output from module: {l} \n')
print(f'The max efficiency polygon for a list of 3-{n-1} vertices = {l[0]} \nThe value of max efficiency = {l[1]}')
# Out:
# The output from module: [7, 1.8019377358048383]
#
# The max efficiency polygon for a list of 3-7 vertices = 7
# The value of max efficiency = 1.8019377358048383

# %%
# Example 2

# Creating an instance of polygon2

n = 20
r = 9
p1 = poly2.polygon2(n,r)

# Finding the max efficiency polygon
l = list(p1.max_efficiency_polygon)
print(f'The output from module: {l} \n')
print(f'The max efficiency polygon for a list of 3-{n-1} vertices = {l[0]} \nThe value of max efficiency = {l[1]}')
# Out:
# The output from module: [19, 4.43862586531225]
#
# The max efficiency polygon for a list of 3-19 vertices = 19
# The value of max efficiency = 4.43862586531225

# %%
# Example 3

# Creating an instance of polygon2

n = 2
r = 9
p1 = poly2.polygon2(n,r)

# Finding the max efficiency polygon
l = list(p1.max_efficiency_polygon)
print(f'The output from module: {l} \n')
print(f'The max efficiency polygon for a list of 3-{n-1} vertices = {l[0]} \nThe value of max efficiency = {l[1]}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-f83f19d204dc> in <module>
#       5 n = 2
#       6 r = 9
# ----> 7 p1 = poly2.polygon2(n,r)
#       8
#       9 # Finding the max efficiency polygon
#
# ~/work/EPAi/Session14/polygon2.py in __init__(self, m, R)
#      10     def __init__(self, m, R):
#      11         if m < 3:
# ---> 12             raise ValueError('m must be greater than 3')
#      13         self._m = m
#      14         self._R = R
#
# ValueError: m must be greater than 3

# %%
# Example 4

# Creating an instance of polygon2

n = 8
r = 0.01
p1 = poly2.polygon2(n,r)

# Finding the max efficiency polygon
l = list(p1.max_efficiency_polygon)
print(f'The output from module: {l} \n')
print(f'The max efficiency polygon for a list of 3-{n-1} vertices = {l[0]} \nThe value of max efficiency = {l[1]}')
# Out:
# The output from module: [7, 0.0045048443395120956]
#
# The max efficiency polygon for a list of 3-7 vertices = 7
# The value of max efficiency = 0.0045048443395120956

# %%
# Example 5

# Creating an instance of polygon2

n = 5
r = 20
p1 = poly2.polygon2(n,r)

# Finding the max efficiency polygon
l = list(p1.max_efficiency_polygon)
print(f'The output from module: {l} \n')
print(f'The max efficiency polygon for a list of 3-{n-1} vertices = {l[0]} \nThe value of max efficiency = {l[1]}')
# Out:
# The output from module: [4, 7.0710678118654755]
#
# The max efficiency polygon for a list of 3-4 vertices = 4
# The value of max efficiency = 7.0710678118654755
